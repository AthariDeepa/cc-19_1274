# %% [markdown]
# <a href="https://colab.research.google.com/github/AthariDeepa/cc-19_1274/blob/main/week2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def subset_sum(arr, n, target):
    # Base cases
    if target == 0:
        return True
    if n == 0 or target < 0:
        return False

    # Include or exclude current element
    return (subset_sum(arr, n - 1, target - arr[n - 1]) or
            subset_sum(arr, n - 1, target))


# Input
n = int(input())
arr = list(map(int, input().split()))
target = int(input())

# Output
print(subset_sum(arr, n, target))
